# %%
import sys  
sys.path.insert(1, '../')

import pandas as pd
from scripts.collaborative_model import CollaborativeModel

# %%
DATA_PATH = "../data/processed_data.csv"
REVIEWS_DATA_PATH = "../data/reviews.csv"

# %%
data = pd.read_csv(DATA_PATH, sep=";")
data["genre"] = data["genre"].apply(eval)
data.head()
# Out:
#                                   book_title           author  \
# 0                                Animal Farm    George Orwell
# 1                         A Clockwork Orange  Anthony Burgess
# 2                                 The Plague     Albert Camus
# 3  An Enquiry Concerning Human Understanding       David Hume
# 4                       A Fire Upon the Deep     Vernor Vinge
#
#   publication_date                                              genre  \
# 0       1945-08-17  [Roman à clef, Satire, Children's literature, ...
# 1             1962  [Science Fiction, Novella, Speculative fiction...
# 2             1947  [Existentialism, Fiction, Absurdist fiction, N...
# 3              NaN                                                 []
# 4              NaN  [Hard science fiction, Science Fiction, Specul...
#
#                                              summary  publication_year  \
# 0   Old Major, the old boar on the Manor Farm, ca...            1945.0
# ...

# %%
reviews = pd.read_csv(REVIEWS_DATA_PATH, sep=";", index_col=0)
reviews.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -2.391304 -2.391304 -2.391304 -2.391304 -2.391304 -2.391304 -2.391304
# 1 -2.363636 -2.363636 -2.363636 -2.363636 -2.363636 -2.363636 -2.363636
# 2 -2.395349 -2.395349 -2.395349 -2.395349 -2.395349 -2.395349 -2.395349
# 3 -2.309524 -2.309524 -2.309524 -2.309524 -2.309524 -2.309524 -2.309524
# 4 -2.193548 -2.193548 -2.193548 -2.193548 -2.193548 -2.193548 -2.193548
#
#           7         8  9  ...  1990  1991  1992  1993  1994      1995  1996  \
# 0 -2.391304 -2.391304  0  ...     0     0     0     0     0  0.000000     0
# 1 -2.363636 -2.363636  0  ...     0     0     0     0     0  0.000000     0
# 2 -2.395349 -2.395349  0  ...     0     0     0     0     0  0.000000     0
# 3 -2.309524 -2.309524  0  ...     0     0     0     0     0  1.690476     0
# 4 -2.193548 -2.193548  0  ...     0     0     0     0     0  0.000000     0
#
#    1997  1998  1999
# 0     0     0     0
# 1     0     0     0
# ...

# %%
collaborative = CollaborativeModel(reviews)

# %%
idx = 1995
pd.DataFrame(data.loc[idx, ["book_title", "author", "genre", "summary"]])
# Out:
#                                                          1995
# book_title                                         Coriolanus
# author                                    William Shakespeare
# genre                                                      []
# summary      The play opens in Rome shortly after the expu...

# %%
idx = 0
pd.DataFrame(data.loc[idx, ["book_title", "author", "genre", "summary"]])
# Out:
#                                                             0
# book_title                                        Animal Farm
# author                                          George Orwell
# genre       [Roman à clef, Satire, Children's literature, ...
# summary      Old Major, the old boar on the Manor Farm, ca...

# %%
my_review = {1995:5, 1:1}
recoms = collaborative.get_recommendations(my_review)
pd.DataFrame(data.loc[recoms, ["book_title", "author", "genre", "summary"]])
# Out:
#                  book_title               author genre  \
# 68         Romeo and Juliet  William Shakespeare    []
# 274    Love's Labour's Lost  William Shakespeare    []
# 190           Julius Caesar  William Shakespeare    []
# 113               Cymbeline  William Shakespeare    []
# 142                 Henry V  William Shakespeare    []
# 519             Richard III  William Shakespeare    []
# 352       The Winter's Tale  William Shakespeare    []
# 51                  Macbeth  William Shakespeare    []
# 540        Henry VI, part 3  William Shakespeare    []
# 106  The Merchant of Venice  William Shakespeare    []
#
#                                                summary
# 68    The play, set in Verona, begins with a street...
# 274   The play opens with the King of Navarre and t...
# 190   Marcus Brutus is Caesar's close friend and a ...
# 113   Imogen (or Innogen), daughter of the British ...
# 142   Elizabethan stages did not use scenery. Ackno...
# ...
